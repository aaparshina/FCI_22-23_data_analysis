# %% [markdown]
# # Анализ данных | Python
# ## ОП «Журналистика», ОП «Медиакоммуникации» 2022/23
#
# ## Семинар 9
#
# ## Введение в визуализацию данных
#
# Во-первых, кроме привычных вам графиков существует еще огромное множество всего (и некоторые вещи работают гораздо лучше привычных нам). Python умеет строить и сложные штуки.
# Есть несколько классных сайтов, которые помогают выбрать подходящий график для ваших данных:
#
# https://www.data-to-viz.com/
#
# https://datavizproject.com/
#
# https://datavizcatalogue.com/RU/

# %%
import matplotlib.pyplot as plt  
import pandas as pd

# %% [markdown]
# ### Кто живет в лесу?
#
# Сначала будем работать с синтетическим набором данных "Кто живет в лесу". У нас есть переменная год и переменные, которые обозначают, сколько в этом году было в лесу зайцев, рысей и морковок.

# %%
forest = pd.read_csv('https://raw.githubusercontent.com/aaparshina/FCI_22-23_data_analysis/main/data/populations.txt', sep='\t')
forest.head()
# Out:
#    year     hare     lynx  carrot
# 0  1900  30000.0   4000.0   48300
# 1  1901  47200.0   6100.0   48200
# 2  1902  70200.0   9800.0   41500
# 3  1903  77400.0  35200.0   38200
# 4  1904  36300.0  59400.0   40600

# %% [markdown]
# ### Самый жестокий фильм?

# %%
movies = pd.read_csv('https://raw.githubusercontent.com/aaparshina/FCI_22-23_data_analysis/main/data/bodycount_Directors_Genra.csv', 
                     index_col=0)
movies.head()
# Out:
#                    Film  Year  Body_Count MPAA_Rating      Genre  \
# 0  24 Hour Party People  2002         7.0           R  Biography
# 1  24 Hour Party People  2002         7.0           R     Comedy
# 2  24 Hour Party People  2002         7.0           R      Drama
# 3  24 Hour Party People  2002         7.0           R      Music
# 4         28 Days Later  2002        53.0           R     Horror
#
#                Director  Length_Minutes  IMDB_Rating  Film_Count  \
# 0  Michael Winterbottom             117          7.3           1
# 1  Michael Winterbottom             117          7.3           1
# 2  Michael Winterbottom             117          7.3           1
# 3  Michael Winterbottom             117          7.3           1
# 4           Danny Boyle             113          7.6           1
#
#    Body_Count_Min
# 0        0.059829
# 1        0.059829
# 2        0.059829
# 3        0.059829
# 4        0.469027

# %% [markdown]
# ### В каком штате США больше всего краж?
#
# Сейчас будем работать с наборам данных, который содержит информацию о количестве преступлений в штатах США в 2005 году.

# %%
crimes = pd.read_csv('https://raw.githubusercontent.com/aaparshina/FCI_22-23_data_analysis/main/data/crimeRatesByState2005.tsv', sep='\t')  # тут разделитель - тоже табуляция
crimes.head()
# Out:
#          state  murder  Forcible_rate  Robbery  aggravated_assult  burglary  \
# 0     Alabama      8.2           34.3    141.4              247.8     953.8
# 1      Alaska      4.8           81.1     80.9              465.1     622.5
# 2     Arizona      7.5           33.8    144.4              327.4     948.4
# 3     Arkansas     6.7           42.9     91.1              386.8    1084.6
# 4  California      6.9           26.0    176.1              317.3     693.3
#
#    larceny_theft  motor_vehicle_theft  population
# 0         2650.0                288.3     4627851
# 1         2599.1                391.0      686293
# 2         2965.2                924.4     6500180
# 3         2711.2                262.1     2855390
# 4         1916.5                712.8    36756666

# %% [markdown]
# ### To be continued...
